# %%
from figs import *
from cluster_visualisations import *
from clustering_helpers import *

# %%
# figuur 5: De relatieve fout van Matrix ACA-T en Vector ACA-T per aantal termen
plot_rel_err(range(5,51,5), [1], ['firebrick'], add_matrix_aca_t=True)
# Out:
# Calculating data (range(5, 51, 5),[1],True,50)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Bachelor Informatica\Bachelorproef\Repository\TensorTimeSeriesClustering\scripts\figs.py:84, in plot_rel_err(ranks, max_approxs, colors, add_matrix_aca_t, repeat, ptype, recompute)
#      83 try:
# ---> 84     data = np.load(f'saved_fig_data/data(err,{ranks},{max_approxs},{add_matrix_aca_t},{repeat}).npy')
#      85     print('data loaded from files')
#
# File c:\Bachelor Informatica\Bachelorproef\Bronnen\AMIE Dataset (PytCharm Project)\venv\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_fig_data/data(err,range(5, 51, 5),[1],True,50).npy'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # figuur 5: De relatieve fout van Matrix ACA-T en Vector ACA-T per aantal termen
# ----> 2 plot_rel_err(range(5,51,5), [1], ['firebrick'], add_matrix_aca_t=True)
#
# File c:\Bachelor Informatica\Bachelorproef\Repository\TensorTimeSeriesClustering\scripts\figs.py:87, in plot_rel_err(ranks, max_approxs, colors, add_matrix_aca_t, repeat, ptype, recompute)
#      85         print('data loaded from files')
#      86     except:
# ---> 87         data, _ = calculate_data(ranks, max_approxs, add_matrix_aca_t, repeat)
#      89 if add_matrix_aca_t:
#      90     colors.append('orange')
#
# File c:\Bachelor Informatica\Bachelorproef\Repository\TensorTimeSeriesClustering\scripts\figs.py:10, in calculate_data(ranks, max_approxs, add_matrix_aca_t, repeat)
#       7 def calculate_data(ranks, max_approxs, add_matrix_aca_t, repeat=1):
#       8     print(f'Calculating data ({ranks},{max_approxs},{add_matrix_aca_t},{repeat})')
# ---> 10     tensor = np.load("saved_tensors/full_tensor.npy")
#      11     t_norm = np.linalg.norm(tensor)
#      13     x_pos = len(ranks)
#
# File c:\Bachelor Informatica\Bachelorproef\Bronnen\AMIE Dataset (PytCharm Project)\venv\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_tensors/full_tensor.npy'

# %%
# figuur 6: De relatieve fout van Matrix ACA-T en Vector ACA-T per relatieve DTW-operaties
plot_rel_err_vs_rel_dtw(range(5,51,5), [1], ['firebrick'], add_matrix_aca_t=True)
# Out:
# data loaded from files

# %%
# figuur 8: De relatieve fout van Vector ACA-T types per aantal termen
plot_rel_err(range(5, 51, 10), [1, 3, 8, 20], ['firebrick', 'greenyellow', 'teal', 'indigo'], add_matrix_aca_t=True, repeat=50, ptype='bar')
# Out:
# data loaded from files

# %%
# figuur 9: De relatieve fout van Vector ACA-T types per relatieve DTW-operaties
plot_rel_err_vs_rel_dtw(range(5, 51, 10), [1, 3, 8, 20], ['firebrick', 'greenyellow', 'teal', 'indigo'], add_matrix_aca_t=False, repeat=50, ptype='line')
# Out:
# data loaded from files

# %%
show_table('rows', 20, "vector_aca_t", 3, 30, 3)
# Out:
# c:\Bachelor Informatica\Bachelorproef\Bronnen\AMIE Dataset (PytCharm Project)\venv\Lib\site-packages\matplotlib\table.py:809: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text=cellText[row][col],

# %%
show_table('tubes', 20, "vector_aca_t", 3, 30, 3)
# Out:
# c:\Bachelor Informatica\Bachelorproef\Bronnen\AMIE Dataset (PytCharm Project)\venv\Lib\site-packages\matplotlib\table.py:809: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text=cellText[row][col],

# %%
#
cluster_ari([1,5,10], 3, 'rows', 10, 10, 50, get_overview()["exercise"], 10, True, True, 4)
